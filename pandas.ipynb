# %% [markdown]
# <a href="https://colab.research.google.com/github/tahminahasan/ML-Notebook/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#series
s1=pd.Series ([1,2,4,5,6,9,3])
s1
# Out:
# 0    1
# 1    2
# 2    4
# 3    5
# 4    6
# 5    9
# 6    3
# dtype: int64

# %%
s2=pd.Series ([2,4,6,8,10,22,12])
s2
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# 5    22
# 6    12
# dtype: int64

# %%
s1+s2
# Out:
# 0     3
# 1     6
# 2    10
# 3    13
# 4    16
# 5    31
# 6    15
# dtype: int64

# %%
s1.describe()
# Out:
# count    7.000000
# mean     4.285714
# std      2.690371
# min      1.000000
# 25%      2.500000
# 50%      4.000000
# 75%      5.500000
# max      9.000000
# dtype: float64

# %%
#data frame
data ={
    'name': ['A', 'B', 'C'],
    'age': [20,21,20],
    'class': [9,10,9],
    'roll': [3,25,30]
}
df=pd.DataFrame(data)
df
# Out:
#   name  age  class  roll
# 0    A   20      9     3
# 1    B   21     10    25
# 2    C   20      9    30

# %%
df.describe()
# Out:
#              age      class       roll
# count   3.000000   3.000000   3.000000
# mean   20.333333   9.333333  19.333333
# std     0.577350   0.577350  14.364308
# min    20.000000   9.000000   3.000000
# 25%    20.000000   9.000000  14.000000
# 50%    20.000000   9.000000  25.000000
# 75%    20.500000   9.500000  27.500000
# max    21.000000  10.000000  30.000000

# %%
df['age'][2]
# Out:
# 20

# %%
#save to csv
df.to_csv("newfile.csv", index=False)

# %%
df=pd.read_csv("/content/iris.csv")
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df=pd.read_csv("/content/iris.csv")
df.head(10)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %%
df.tail(7)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 143           6.8          3.2           5.9          2.3  Virginica
# 144           6.7          3.3           5.7          2.5  Virginica
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
df.to_numpy()
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'Setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'Setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'Setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'Setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'Setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'Setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'Setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'Setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'Setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'Setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'Setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'Setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'Setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'Setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'Setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'Setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'Setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'Setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'Setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'Setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'Setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'Setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'Setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'Setosa'],
# ...

# %%
#loc
#loc → Uses actual row labels and column names (includes last row).
newdf=df.loc[10:15,("sepal.length", "sepal.width")]
newdf
# Out:
#     sepal.length  sepal.width
# 10           5.4          3.7
# 11           4.8          3.4
# 12           4.8          3.0
# 13           4.3          3.0
# 14           5.8          4.0
# 15           5.7          4.4

# %%
#loc
newdf=df.loc[:,("sepal.length", "sepal.width")]
newdf
# Out:
#      sepal.length  sepal.width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
#iloc
#iloc → Uses integer index positions (excludes last row)
newdf=df.iloc[10:20,1:4]
newdf.head()
# Out:
#     sepal.width  petal.length  petal.width
# 10          3.7           1.5          0.2
# 11          3.4           1.6          0.2
# 12          3.0           1.4          0.1
# 13          3.0           1.1          0.1
# 14          4.0           1.2          0.2

# %%
pdf=df.loc[(df['sepal.width']>3.6) & (df['petal.length']> 1.5) ]
pdf
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 5             5.4          3.9           1.7          0.4     Setosa
# 18            5.7          3.8           1.7          0.3     Setosa
# 44            5.1          3.8           1.9          0.4     Setosa
# 46            5.1          3.8           1.6          0.2     Setosa
# 117           7.7          3.8           6.7          2.2  Virginica
# 131           7.9          3.8           6.4          2.0  Virginica

# %%
#drop
new = pdf.drop(['petal.width'],axis=1)
new.to_csv("newfile.csv")

# %%
df= pd.DataFrame({
    'ID': [101, 102, 102, 103, 104, 104,104],
    'Name': ['Alice', 'Bob', 'Bob', 'Charlie', 'David', 'David','David'],
    'Age': [23, 25, 25, 28, 22, 22,22],
    'Score': [85, 90, 90, 78, 92, 92, 92]
})
df
# Out:
#     ID     Name  Age  Score
# 0  101    Alice   23     85
# 1  102      Bob   25     90
# 2  102      Bob   25     90
# 3  103  Charlie   28     78
# 4  104    David   22     92
# 5  104    David   22     92
# 6  104    David   22     92

# %%
df.drop_duplicates(subset='Name', keep='last')
# Out:
#     ID     Name  Age  Score
# 0  101    Alice   23     85
# 2  102      Bob   25     90
# 3  103  Charlie   28     78
# 6  104    David   22     92

# %%
df= pd.DataFrame( {
    'Name': ['Alice', 'Bob', 'Bob', 'Charlie', 'David', 'Eve', 'Frank'],
    'Age': [25, 30, 30, None, 22, 28, None],
    'Score': [85, None, None, 78, 92, None, 88]
})
df
# Out:
#       Name   Age  Score
# 0    Alice  25.0   85.0
# 1      Bob  30.0    NaN
# 2      Bob  30.0    NaN
# 3  Charlie   NaN   78.0
# 4    David  22.0   92.0
# 5      Eve  28.0    NaN
# 6    Frank   NaN   88.0

# %%
df['Age'].mean()
# Out:
# 27.0

# %%
#fill the null
x=df['Age'].mean()
df['Age'].fillna(x,inplace=True)
df
# Out:
# <ipython-input-25-96b4b3aa84a9>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(x,inplace=True)
#       Name   Age  Score
# 0    Alice  25.0   85.0
# 1      Bob  30.0    NaN
# 2      Bob  30.0    NaN
# 3  Charlie  27.0   78.0
# 4    David  22.0   92.0
# 5      Eve  28.0    NaN
# 6    Frank  27.0   88.0

# %%
df.sort_index(axis=0, ascending=False)
# Out:
#       Name   Age  Score
# 6    Frank  27.0   88.0
# 5      Eve  28.0    NaN
# 4    David  22.0   92.0
# 3  Charlie  27.0   78.0
# 2      Bob  30.0    NaN
# 1      Bob  30.0    NaN
# 0    Alice  25.0   85.0
