# %% [markdown]
# <a href="https://colab.research.google.com/github/tahminahasan/ML-Notebook/blob/main/Decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn import tree

# %%
df1= pd.read_csv('titanic.csv')
df1.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df2=df1[['Survived', 'Pclass', 'Sex', 'Age', 'Fare']]
df2.head(1)
# Out:
#    Survived  Pclass   Sex   Age  Fare
# 0         0       3  male  22.0  7.25

# %%
df2.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# Fare          0
# dtype: int64

# %%
df2.shape
# Out:
# (891, 5)

# %%
df3=df2.copy()
df3.head(1)
# Out:
#    Survived  Pclass   Sex   Age  Fare
# 0         0       3  male  22.0  7.25

# %%
df3.Age = df3.Age.fillna(df3.Age.mean())
df3.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# Fare        0
# dtype: int64

# %%
le_sex = LabelEncoder()
df3['Gender'] = le_sex.fit_transform(df3.Sex)
df3.head(5)
# Out:
#    Survived  Pclass     Sex   Age     Fare  Gender
# 0         0       3    male  22.0   7.2500       1
# 1         1       1  female  38.0  71.2833       0
# 2         1       3  female  26.0   7.9250       0
# 3         1       1  female  35.0  53.1000       0
# 4         0       3    male  35.0   8.0500       1

# %%
x = df3.drop(['Survived', 'Sex'], axis=1)
y=df3.Survived

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
model = tree.DecisionTreeClassifier()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(x_test, y_test)
# Out:
# 0.7932960893854749

# %%
x_test.head(5)
# Out:
#      Pclass        Age      Fare  Gender
# 495       3  29.699118   14.4583       1
# 648       3  29.699118    7.5500       1
# 278       3   7.000000   29.1250       1
# 31        1  29.699118  146.5208       0
# 255       3  29.000000   15.2458       0

# %%
y_test.head(5)
# Out:
# 495    0
# 648    0
# 278    0
# 31     1
# 255    1
# Name: Survived, dtype: int64

# %%
model.predict([[1,29.699118,	146.5208,	0 ]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])
